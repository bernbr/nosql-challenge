# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query1 = {'scores.Hygiene': 20}
# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query1)) 
# Display the first document in the results using pprint
print("First result:")
results1 = establishments.find(query1)
pprint(results1[0])
# Out:
# Number of documents in result: 41
# First result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64147d67d03467887a497045'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results_df1 = pd.DataFrame(results1)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(results_df1)) 
# Display the first 10 rows of the DataFrame
results_df1.head(10)
# Out:
# Number of rows in result:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64147d67d03467887a497045   110681                  0
# 1  64147d67d03467887a4973c6   612039                  0
# 2  64147d67d03467887a4976cc   730933                  0
# 3  64147d67d03467887a4978bc   172735                  0
# 4  64147d67d03467887a4978c9   172953                  0
# 5  64147d67d03467887a49826b   512854                  0
# 6  64147d67d03467887a498491  1537089                  0
# 7  64147d67d03467887a4999b6   155648                  0
# 8  64147d67d03467887a499dfa  1012883                  0
# 9  64147d67d03467887a49a60c   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {'LocalAuthorityName': {'$regex': 'London'}, 
          'RatingValue': {'$gte': '4'}
         }
# Use count_documents to display the number of documents in the result
print("Number of documents in result: ", establishments.count_documents(query2)) 
# Display the first document in the results using pprint
print("First result:")
results2 = establishments.find(query2)
pprint(results2[0])
# Out:
# Number of documents in result:  34
# First result:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64147d67d03467887a498a60'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
results_df2 = pd.DataFrame(results2)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(results_df2)) 
# Display the first 10 rows of the DataFrame
results_df2.head(10)
# Out:
# Number of rows in result:  34
#                         _id   FHRSID  ChangesByServerID  \
# 0  64147d67d03467887a498a60   621707                  0
# 1  64147d67d03467887a498d87  1130836                  0
# 2  64147d67d03467887a4998d3   293783                  0
# 3  64147d67d03467887a49a6d1  1315095                  0
# 4  64147d67d03467887a49a6d2   294474                  0
# 5  64147d67d03467887a49addc   294900                  0
# 6  64147d67d03467887a49cee4  1252616                  0
# 7  64147d67d03467887a49cee8   293756                  0
# 8  64147d68d03467887a49d2b1   878523                  0
# 9  64147d68d03467887a49d2cb   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000035653                             Froottree
# 7             PI/000002538                         Tereza Joanne
# 8             PI/000029844                      Brick Lane Brews
# 9             PI/000002585         The Nuance Group (UK) Limited
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Other catering premises            7841
# 8  Restaurant/Cafe/Canteen               1
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6                   Tereza Joanne King George V Lock
# 7  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 8                       Air side London City Airport
# 9                  Duty Free Shop Passenger Terminal
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6             Woolwich Manor Way London     Charlton  ...
# 7                                London               ...
# 8                                London               ...
# 9  London City AirportRoyal DocksLondon               ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 7  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6  {'longitude': 0.0693250000476837, 'latitude': ...
# 7     {'longitude': 0.069286, 'latitude': 51.501121}
# 8     {'longitude': 0.048006, 'latitude': 51.503733}
# 9     {'longitude': 0.047966, 'latitude': 51.504112}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.300000            False
# 7  4648.301822            False
# 8  4649.173485            False
# 9  4649.188826            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query3 = {'RatingValue': '5', 
         'geocode.latitude': {'$gte': latitude-degree_search}, 
         'geocode.latitude': {'$lte': latitude-degree_search},
         'geocode.longitude': {'$gte': longitude-degree_search},
         'geocode.longitude': {'$lte': longitude-degree_search}
        }
sort3 = [('scores.Hygiene', -1)]

results3 = establishments.find(query3).sort(sort3)

print("Number of documents in result: ", establishments.count_documents(query3)) 

# Print the results
print("First result:")
pprint(results3[0])
# Out:
# Number of documents in result:  1453
# First result:
# {'AddressLine1': 'Unit E7',
#  'AddressLine2': 'Eastside Business Park',
#  'AddressLine3': 'Beach Road',
#  'AddressLine4': '',
#  'BusinessName': 'Mamoosh Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4622.5695519854335,
#  'FHRSID': 1264191,
#  'LocalAuthorityBusinessID': 'PI/000064924',
#  'LocalAuthorityCode': '105',
#  'LocalAuthorityEmailAddress': 'ehealth.ldc@lewes-eastbourne.gov.uk',
#  'LocalAuthorityName': 'Lewes',
#  'LocalAuthorityWebSite': 'http://www.lewes-eastbourne.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN9 0FB',
#  'RatingDate': '2021-07-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64147d67d03467887a497c4d'),
#  'geocode': {'latitude': Decimal128('50.7882587'),
#              'longitude': Decimal128('0.06121')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1264191',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
results_df3 = pd.DataFrame(results3)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(results_df3)) 
# Display the first 10 rows of the DataFrame
results_df3.head(10)
# Out:
# Number of rows in result:  1453
#                         _id   FHRSID  ChangesByServerID  \
# 0  64147d67d03467887a497c4d  1264191                  0
# 1  64147d67d03467887a497c62  1412076                  0
# 2  64147d67d03467887a497c78   664256                  0
# 3  64147d67d03467887a497c7b  1394055                  0
# 4  64147d67d03467887a497cb4   801798                  0
# 5  64147d67d03467887a497ccb   167144                  0
# 6  64147d67d03467887a497ce7   643980                  0
# 7  64147d67d03467887a497ced   167132                  0
# 8  64147d67d03467887a497d07   168341                  0
# 9  64147d67d03467887a497d10   168429                  0
#
#   LocalAuthorityBusinessID                    BusinessName  \
# 0             PI/000064924                     Mamoosh Ltd
# 1             PI/000066449             Thai Star Foods Ltd
# 2             PI/000012088                         Nippers
# 3             PI/000011404        Rough & Ready Wholefoods
# 4             PI/000035182                  Oakhouse Foods
# 5             PI/000010831                   Brewers Fayre
# 6             PI/000011513  Twiglets Forest School Nursery
# 7             PI/000010819   Southdown Housing Association
# 8             PI/000012997          Newhaven Kebab & Pizza
# 9             PI/000013180                    Bickerstaffs
#
#                 BusinessType  BusinessTypeID             AddressLine1  \
# 0          Retailers - other            4613                  Unit E7
# 1        Importers/Exporters              14          Logistics House
# 2    Restaurant/Cafe/Canteen               1         Shakespeare Hall
# 3  Distributors/Transporters               7      Bevan Funnell House
# 4          Retailers - other            4613              Alarian Ltd
# 5    Restaurant/Cafe/Canteen               1  The Drove Brewers Fayre
# 6    Restaurant/Cafe/Canteen               1     Grays Nursery Annexe
# 7            Caring Premises               5            50A Avis Road
# 8     Takeaway/sandwich shop            7844            59 South Road
# 9          Retailers - other            4613      West Quay Fisheries
#
#                   AddressLine2 AddressLine3  ...  \
# 0       Eastside Business Park   Beach Road  ...
# 1                   Beach Road     Newhaven  ...
# 2  Fort Road Recreation Ground    Fort Road  ...
# 3                  Norton Road     Newhaven  ...
# 4                  Estate Road     Newhaven  ...
# 5                    The Drove     Newhaven  ...
# 6                 Railway Road     Newhaven  ...
# 7                     Newhaven  East Sussex  ...
# 8                     Newhaven  East Sussex  ...
# 9                    Riverside     Newhaven  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.06121, 'latitude': 50.7882587}
# 1  {'longitude': 0.0584929995238781, 'latitude': ...
# 2   {'longitude': 0.0525946, 'latitude': 50.7852495}
# 3  {'longitude': 0.0580499991774559, 'latitude': ...
# 4     {'longitude': 0.056643, 'latitude': 50.793386}
# 5     {'longitude': 0.058678, 'latitude': 50.796409}
# 6      {'longitude': 0.055798, 'latitude': 50.79449}
# 7     {'longitude': 0.061378, 'latitude': 50.800696}
# 8      {'longitude': 0.05084, 'latitude': 50.791762}
# 9      {'longitude': 0.05195, 'latitude': 50.793136}
#
#       Distance NewRatingPending  \
# 0  4622.569552            False
# 1  4622.687755            False
# 2  4622.780056            False
# 3  4622.785523            False
# 4  4622.925660            False
# 5  4622.960070            False
# 6  4622.997196            False
# 7  4623.015797            False
# 8  4623.082078            False
# 9  4623.090832            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 7  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 8  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
# 9  [{'rel': 'self', 'href': 'https://api.ratings....      None     None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
